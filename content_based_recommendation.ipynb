# %% [markdown]
# In this project, it is aimed to find similar books according to their contents. Goodreads book dataset was used. The similarities were calculated by TF-IDF (term frequency- inverse document frequency) and cosine similarity.
#
# The method is to vectorize the words in each row of the related column in a matrix, i.e TF-IDF matrix here. CountVectorizer matrix also can be used, however it can cause a bias in favor of the words having high frequency. TF-IDF normalizes this bias.

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
pd.set_option("display.max_columns", None)

# %%
df = pd.read_csv(r"C:\Users\PC\Documents\books_enriched.csv")

# %%
df.shape
# Out:
# (10000, 30)

# %%
df.head(20)
# Out:
#     Unnamed: 0  index                                            authors  \
# 0            0      0                                ['Suzanne Collins']
# 1            1      1                  ['J.K. Rowling', 'Mary GrandPré']
# 2            2      2                                ['Stephenie Meyer']
# 3            3      3                                     ['Harper Lee']
# 4            4      4                            ['F. Scott Fitzgerald']
# 5            5      5                                     ['John Green']
# 6            6      6                                 ['J.R.R. Tolkien']
# 7            7      7                                  ['J.D. Salinger']
# 8            8      8                                      ['Dan Brown']
# 9            9      9                                    ['Jane Austen']
# 10          10     10                                ['Khaled Hosseini']
# 11          11     11                                  ['Veronica Roth']
# 12          12     12  ['Anne Frank', 'Eleanor Roosevelt', 'B.M. Mooy...
# 13          13     13                   ['Stieg Larsson', 'Reg Keeland']
# 14          14     14                                ['Suzanne Collins']
# 15          15     15    ['J.K. Rowling', 'Mary GrandPré', 'Rufus Beck']
# 16          16     16                                ['Suzanne Collins']
# 17          17     17                  ['J.K. Rowling', 'Mary GrandPré']
# 18          18     18                                   ['Alice Sebold']
# 19          19     19                  ['J.K. Rowling', 'Mary GrandPré']
#
#     average_rating  best_book_id  book_id  books_count  \
# 0             4.34       2767052        1          272
# 1             4.44             3        2          491
# 2             3.57         41865        3          226
# 3             4.25          2657        4          487
# 4             3.89          4671        5         1356
# 5             4.26      11870085        6          226
# 6             4.25          5907        7          969
# 7             3.79          5107        8          360
# 8             3.85           960        9          311
# 9             4.24          1885       10         3455
# 10            4.26         77203       11          283
# 11            4.24      13335037       12          210
# 12            4.10         48855       15          710
# 13            4.11       2429135       16          274
# 14            4.30       6148028       17          201
# 15            4.53             5       18          376
# 16            4.03       7260188       20          239
# 17            4.46             2       21          307
# 18            3.77      12232938       22          183
# 19            4.37         15881       23          398
#
#                                           description  \
# 0   WINNING MEANS FAME AND FORTUNE.LOSING MEANS CE...
# 1   Harry Potter's life is miserable. His parents ...
# 2   About three things I was absolutely positive.\...
# 3   The unforgettable novel of a childhood in a sl...
# 4   Alternate Cover Edition ISBN: 0743273567 (ISBN...
# 5   Despite the tumor-shrinking medical miracle th...
# 6   In a hole in the ground there lived a hobbit. ...
# 7   The hero-narrator of The Catcher in the Rye is...
# 8   World-renowned Harvard symbologist Robert Lang...
# 9   Alternate cover edition of ISBN 9780679783268S...
# 10  The unforgettable, heartbreaking story of the ...
# 11  In Beatrice Prior's dystopian Chicago world, s...
# 12  Discovered in the attic in which she spent the...
# 13  Harriet Vanger, a scion of one of Sweden’s wea...
# 14  SPARKS ARE IGNITING.FLAMES ARE SPREADING.AND T...
# 15  Harry Potter's third year at Hogwarts is full ...
# 16  The final book in the ground-breaking HUNGER G...
# 17  There is a door at the end of a silent corrido...
# 18  "My name was Salmon, like the fish; first name...
# 19  Ever since Harry Potter had come home for the ...
#
#                                                genres  goodreads_book_id  \
# 17  https://images.gr-assets.com/books/1387141547s...
# 18  https://images.gr-assets.com/books/1457810586s...
# 19  https://images.gr-assets.com/books/1474169725s...
#
#                                                 title   work_id  \
# 0             The Hunger Games (The Hunger Games, #1)   2792775
# 1   Harry Potter and the Sorcerer's Stone (Harry P...   4640799
# 2                             Twilight (Twilight, #1)   3212258
# 3                               To Kill a Mockingbird   3275794
# 4                                    The Great Gatsby    245494
# 5                              The Fault in Our Stars  16827462
# 6                                          The Hobbit   1540236
# 7                              The Catcher in the Rye   3036731
# 8               Angels & Demons  (Robert Langdon, #1)   3338963
# 9                                 Pride and Prejudice   3060926
# 10                                    The Kite Runner   3295919
# 11                          Divergent (Divergent, #1)  13155899
# 12                          The Diary of a Young Girl   3532896
# 13   The Girl with the Dragon Tattoo (Millennium, #1)   1708725
# 14               Catching Fire (The Hunger Games, #2)   6171458
# 15  Harry Potter and the Prisoner of Azkaban (Harr...   2402163
# 16                  Mockingjay (The Hunger Games, #3)   8812783
# 17  Harry Potter and the Order of the Phoenix (Har...   2809203
# 18                                   The Lovely Bones   1145090
# 19  Harry Potter and the Chamber of Secrets (Harry...   6231171
#
#     work_ratings_count  work_text_reviews_count  \
# 0              4942365                   155254
# 1              4800065                    75867
# 2              3916824                    95009
# 3              3340896                    72586
# 4              2773745                    51992
# 5              2478609                   140739
# 6              2196809                    37653
# 7              2120637                    44920
# 8              2078754                    25112
# 9              2191465                    49152
# 10             1878095                    59730
# 11             2216814                   101023
# 12             2024493                    20825
# 13             1929834                    62543
# 14             1988079                    88538
# 15             1969375                    36099
# 16             1870748                    96274
# 17             1840548                    28685
# 18             1661562                    36642
# 19             1906199                    34172
#
#                                             authors_2
# 0                                 ['Suzanne Collins']
# 1                   ['J.K. Rowling', 'Mary GrandPré']
# 2                                 ['Stephenie Meyer']
# 3                                      ['Harper Lee']
# 4                             ['F. Scott Fitzgerald']
# 5                                      ['John Green']
# 6                                  ['J.R.R. Tolkien']
# 7                                   ['J.D. Salinger']
# 8                                       ['Dan Brown']
# 9                                     ['Jane Austen']
# 10                                ['Khaled Hosseini']
# 11                                  ['Veronica Roth']
# 12  ['Anne Frank', 'Eleanor Roosevelt', 'B.M. Mooy...
# 13                   ['Stieg Larsson', 'Reg Keeland']
# 14                                ['Suzanne Collins']
# 15    ['J.K. Rowling', 'Mary GrandPré', 'Rufus Beck']
# 16                                ['Suzanne Collins']
# 17                  ['J.K. Rowling', 'Mary GrandPré']
# 18                                   ['Alice Sebold']
# 19                  ['J.K. Rowling', 'Mary GrandPré']

# %%
df = df.drop("Unnamed: 0", axis=1)

# %%
# The 'description' column gives idea about the content, so this will be used. Some rows contain unrelevant information, so
# they are removed.

df["description"].str.contains("ISBN", na=False).value_counts()
# Out:
# False    9838
# True      162
# Name: description, dtype: int64

# %%
df["description"].str.contains("cover edition", na=False).value_counts()
# Out:
# False    9790
# True      210
# Name: description, dtype: int64

# %%
df = df[~df["description"].str.contains("ISBN", na=False)]

# %%
df = df[~df["description"].str.contains("cover edition", na=False)]

# %%
df["description"].head()
# Out:
# 0    WINNING MEANS FAME AND FORTUNE.LOSING MEANS CE...
# 1    Harry Potter's life is miserable. His parents ...
# 2    About three things I was absolutely positive.\...
# 3    The unforgettable novel of a childhood in a sl...
# 5    Despite the tumor-shrinking medical miracle th...
# Name: description, dtype: object

# %%
# String operations are done before applying cosine similarity.

df['description'] = df['description'].str.lower()
df['description'] = df['description'].str.replace(r'[^\w\s]+', ' ')
df['description'] = df['description'].str.replace('\n', ' ')
# Out:
# C:\Users\PC\AppData\Local\Temp/ipykernel_5280/299666640.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['description'] = df['description'].str.replace(r'[^\w\s]+', ' ')

# %%
# stop_words are commonly used but have no meaning, like 'is', 'the', etc.

tfidf = TfidfVectorizer(stop_words = 'english')

# %%
df['description'].isna().sum()
# Out:
# 57

# %%
df['description'] = df['description'].fillna(' ')

# %%
df['description'].head(20)
# Out:
# 0     winning means fame and fortune losing means ce...
# 1     harry potter s life is miserable  his parents ...
# 2     about three things i was absolutely positive  ...
# 3     the unforgettable novel of a childhood in a sl...
# 5     despite the tumor shrinking medical miracle th...
# 6     in a hole in the ground there lived a hobbit  ...
# 7     the hero narrator of the catcher in the rye is...
# 8     world renowned harvard symbologist robert lang...
# 10    the unforgettable  heartbreaking story of the ...
# 11    in beatrice prior s dystopian chicago world  s...
# 12    discovered in the attic in which she spent the...
# 14    sparks are igniting flames are spreading and t...
# 15    harry potter s third year at hogwarts is full ...
# 16    the final book in the ground breaking hunger g...
# 17    there is a door at the end of a silent corrido...
# 18     my name was salmon  like the fish  first name...
# 19    ever since harry potter had come home for the ...
# 20    harry potter is midway through his training as...
# 21    harry potter is leaving privet drive for the l...
# 23    the war against voldemort is not going well  e...
# Name: description, dtype: object

# %%
tfidf_matrix = tfidf.fit_transform(df["description"])

# %%
# Similarity matrix is generated using cosine similarity.

cos_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)

# %%
cos_sim
# Out:
# array([[1.        , 0.02322108, 0.01937285, ..., 0.01476556, 0.00422354,
#         0.00959166],
#        [0.02322108, 1.        , 0.        , ..., 0.03664043, 0.01163007,
#         0.01411476],
#        [0.01937285, 0.        , 1.        , ..., 0.        , 0.        ,
#         0.00587242],
#        ...,
#        [0.01476556, 0.03664043, 0.        , ..., 1.        , 0.01077162,
#         0.02375643],
#        [0.00422354, 0.01163007, 0.        , ..., 0.01077162, 1.        ,
#         0.00441835],
#        [0.00959166, 0.01411476, 0.00587242, ..., 0.02375643, 0.00441835,
#         1.        ]])

# %%
# In order to find the similar books, first books are ordered by their indices.

indices = pd.Series(df.index, index=df["title"])

# %%
indices
# Out:
# title
# The Hunger Games (The Hunger Games, #1)                        0
# Harry Potter and the Sorcerer's Stone (Harry Potter, #1)       1
# Twilight (Twilight, #1)                                        2
# To Kill a Mockingbird                                          3
# The Fault in Our Stars                                         5
#                                                             ...
# Anastasia Krupnik (Anastasia Krupnik, #1)                   9994
# Feverborn (Fever, #8)                                       9996
# Breaking Point (Tom Clancy's Net Force, #4)                 9997
# Chasing The Night (Eve Duncan, #11; Catherine Ling, #1)     9998
# The First World War                                         9999
# Length: 9691, dtype: int64

# %%
indices.shape
# Out:
# (9691,)

# %%
# Duplicated values are removed.

indices = indices[~indices.index.duplicated(keep='last')]

# %%
indices.shape
# Out:
# (9656,)

# %%
# A random book is chosen, Pet Sematary by Stephen King.

book_index = indices["The Green Mile"]

# %%
# The similarity matrix of the chosen book.

cos_sim[book_index]
# Out:
# array([0.01025581, 0.01809545, 0.0038223 , ..., 0.        , 0.        ,
#        0.00956674])

# %%
# To get a better view, the matrix is converted to a dataframe.

similarity_scores = pd.DataFrame(cos_sim[book_index], columns = ['score'])

# %%
similarity_scores
# Out:
#          score
# 0     0.010256
# 1     0.018095
# 2     0.003822
# 3     0.034342
# 4     0.006334
# ...        ...
# 9686  0.000000
# 9687  0.002570
# 9688  0.000000
# 9689  0.000000
# 9690  0.009567
#
# [9691 rows x 1 columns]

# %%
# Most similar 20 books are chosen.

most_similar= similarity_scores.sort_values(by='score', ascending=False)[1:21]

# %%
book_indices = most_similar.index

# %%
# The similar books to the chosen book, with their titles and genres

similar_books = df[['title', 'genres']].iloc[book_indices]

# %%
similar_books
# Out:
#                                            title  \
# 6014                               Never Knowing
# 3232                             When It Happens
# 84                             The Secret Garden
# 4836                     Undone (Will Trent, #3)
# 5431             Beyond Reach (Grant County, #6)
# 6429                     Unseen (Will Trent, #7)
# 2223             Blindsighted (Grant County, #1)
# 4794        A Faint Cold Fear (Grant County, #3)
# 2407  Beautiful Stranger (Beautiful Bastard, #2)
# 4949                  Kisscut (Grant County, #2)
# 5125                Faithless (Grant County, #5)
# 4323                Indelible (Grant County, #4)
# 8415                           The Winter People
# 5061       The Readers of Broken Wheel Recommend
# 8041       Danger in the Shadows (O'Malley #0.5)
# 3794        Into the Wilderness (Wilderness, #1)
# 7666                      Little Lord Fauntleroy
# 9512            The Last Painting of Sara de Vos
# 8758                         Bedtime for Frances
# 7088      Palace of Stone (Princess Academy, #2)
#
#                                                  genres
# 6014  ['thriller', 'mystery', 'fiction', 'suspense',...
# 3232  ['young-adult', 'romance', 'contemporary', 'ch...
# 84    ['classics', 'fiction', 'young-adult', 'histor...
# 4836  ['thriller', 'mystery', 'crime', 'fiction', 's...
# 5431  ['mystery', 'thriller', 'crime', 'fiction', 's...
# 6429  ['mystery', 'thriller', 'crime', 'fiction', 's...
# 2223  ['mystery', 'thriller', 'crime', 'fiction', 's...
# 4794  ['mystery', 'thriller', 'crime', 'fiction', 's...
# 2407  ['romance', 'contemporary', 'chick-lit', 'fict...
# 4949  ['mystery', 'thriller', 'crime', 'fiction', 's...
# 5125  ['mystery', 'thriller', 'crime', 'fiction', 's...
# 4323  ['mystery', 'thriller', 'crime', 'fiction', 's...
# 8415  ['horror', 'mystery', 'fiction', 'thriller', '...
# 5061  ['fiction', 'romance', 'contemporary', 'chick-...
# 8041  ['christian', 'romance', 'mystery', 'fiction',...
# 3794       ['historical-fiction', 'romance', 'fiction']
# 7666  ['classics', 'fiction', 'historical-fiction', ...
# 9512  ['historical-fiction', 'fiction', 'art', 'myst...
# 8758                 ['fiction', 'classics', 'fantasy']
# 7088   ['fantasy', 'young-adult', 'fiction', 'romance']

# %%
df[df["title"] == "The Green Mile"]
# Out:
#      index           authors  average_rating  best_book_id  book_id  \
# 450    450  ['Stephen King']            4.42         11566      488
#
#      books_count                                        description  \
# 450          162  when it first appeared  one volume per month  ...
#
#                                                 genres  goodreads_book_id  \
# 450  ['horror', 'fiction', 'fantasy', 'thriller', '...              11566
#
#                                              image_url       isbn  \
# 450  https://images.gr-assets.com/books/1373903563m...  451933028
#
#            isbn13 language_code  original_publication_year  original_title  \
# 450  9.780452e+12           eng                     1996.0  The Green Mile
#
#      pages publishDate  ratings_1  ratings_2  ratings_3  ratings_4  ratings_5  \
# 450  592.0    09/01/96        725       3044      19770      59813     107757
#
#      ratings_count                                    small_image_url  \
# 450         173950  https://images.gr-assets.com/books/1373903563s...
#
#               title  work_id  work_ratings_count  work_text_reviews_count  \
# 450  The Green Mile    15599              191109                     4873
#
#             authors_2
# 450  ['Stephen King']

# %%
# The dataframe of the similar books with The Green Mile

similar_books_df = pd.merge(similar_books[['title', 'genres']], df, how='left', on='title')

# %%
similar_books_df
# Out:
#                                          title  \
# 0                                Never Knowing
# 1                              When It Happens
# 2                            The Secret Garden
# 3                      Undone (Will Trent, #3)
# 4              Beyond Reach (Grant County, #6)
# 5                      Unseen (Will Trent, #7)
# 6              Blindsighted (Grant County, #1)
# 7         A Faint Cold Fear (Grant County, #3)
# 8   Beautiful Stranger (Beautiful Bastard, #2)
# 9                   Kisscut (Grant County, #2)
# 10                Faithless (Grant County, #5)
# 11                Indelible (Grant County, #4)
# 12                           The Winter People
# 13       The Readers of Broken Wheel Recommend
# 14       Danger in the Shadows (O'Malley #0.5)
# 15        Into the Wilderness (Wilderness, #1)
# 16                      Little Lord Fauntleroy
# 17            The Last Painting of Sara de Vos
# 18                         Bedtime for Frances
# 19      Palace of Stone (Princess Academy, #2)
#
#                                              genres_x  index  \
# 0   ['thriller', 'mystery', 'fiction', 'suspense',...   6014
# 1   ['young-adult', 'romance', 'contemporary', 'ch...   3232
# 2   ['classics', 'fiction', 'young-adult', 'histor...     84
# 3   ['thriller', 'mystery', 'crime', 'fiction', 's...   4836
# 4   ['mystery', 'thriller', 'crime', 'fiction', 's...   5431
# 5   ['mystery', 'thriller', 'crime', 'fiction', 's...   6429
# 6   ['mystery', 'thriller', 'crime', 'fiction', 's...   2223
# 7   ['mystery', 'thriller', 'crime', 'fiction', 's...   4794
# 8   ['romance', 'contemporary', 'chick-lit', 'fict...   2407
# 9   ['mystery', 'thriller', 'crime', 'fiction', 's...   4949
# 10  ['mystery', 'thriller', 'crime', 'fiction', 's...   5125
# 11  ['mystery', 'thriller', 'crime', 'fiction', 's...   4323
# 12  ['horror', 'mystery', 'fiction', 'thriller', '...   3428
# 13  ['fiction', 'romance', 'contemporary', 'chick-...   5061
# 14  ['christian', 'romance', 'mystery', 'fiction',...   8041
# 15       ['historical-fiction', 'romance', 'fiction']   3794
# 16  ['classics', 'fiction', 'historical-fiction', ...   7666
# 17  ['historical-fiction', 'fiction', 'art', 'myst...   8581
# 18                 ['fiction', 'classics', 'fantasy']   5491
# 19   ['fantasy', 'young-adult', 'fiction', 'romance']   7088
#
#                                   authors  average_rating  best_book_id  \
# 0                       ['Chevy Stevens']            3.85      10169662
# 1                    ['Susane Colasanti']            3.74        781046
# 2             ['Frances Hodgson Burnett']            4.12          2998
# 3                     ['Karin Slaughter']            4.24       5764902
# 4                     ['Karin Slaughter']            4.19         21720
# 5                     ['Karin Slaughter']            4.17      16071767
# 6                     ['Karin Slaughter']            4.10         21718
# 7                     ['Karin Slaughter']            4.12         21721
# 8                    ['Christina Lauren']            4.24      16117506
# 9                     ['Karin Slaughter']            4.12         21719
# 10                    ['Karin Slaughter']            4.11         21722
# 11                    ['Karin Slaughter']            4.19        182012
# 12                ['[Jennifer  McMahon]']            3.76      18007535
# 13   ['Katarina Bivald', 'Alice Menzies']            3.56      25573977
# 14                      ['Dee Henderson']            4.33        359463
# 15                        ['Sara Donati']            4.10         72854
# 16            ['Frances Hodgson Burnett']            3.81        275247
# 17                    ['[Dominic Smith]']            3.83      25664459
# 18  ['[Russell Hoban', 'Garth Williams]']            4.14        906541
# 19                       ['Shannon Hale']            3.95      12926132
#
#     book_id  books_count                                        description  \
# 0      6907           56  at thirty three sara gallagher is finally happ...
# 1      3487           26  at the start of her senior year in high school...
# 2        93         1350   one of the most delightful and enduring class...
# 3      5408           84  when a tortured young woman enters the trauma ...
# 4      6151           60  sara linton resident medical examiner pediatri...
# 5      7474           46  karin slaughter s novels featuring special age...
# 6      2373           96  a small georgia town erupts in panic when a yo...
# 7      5359           79  the third pulse pounding novel in the grant co...
# 8      2576           40  escaping a cheating ex  finance whiz sara dill...
# 9      5548           73  saturday night dates at the skating rink have ...
# 10     5771           61  the victim was buried alive in the georgia woo...
# 11     4794           72  an officer is shot point blank in the grant co...
# 12     3429           37  west hall  vermont  has always been a town of ...
# 13     5687           63  once you let a book into your life  the most u...
# 14     9824           28  sara is terrified  she s doing the one thing s...
# 15     4148           27  weaving a tapestry of fact and fiction  sara d...
# 16     9255          442  little lord fauntleroy by frances hodgson burn...
# 17     8582           22  this is what we long for  the profound pleasur...
# 18     5492           26  the big hand of the clock is at 12 the little ...
# 19     8378           18  coming down from the mountain to a new life in...
#
#                                              genres_y  goodreads_book_id  \
# 0   ['thriller', 'mystery', 'fiction', 'suspense',...           10169662
# 1   ['young-adult', 'romance', 'contemporary', 'ch...             781046
# 2   ['classics', 'fiction', 'young-adult', 'histor...               2998
# 3   ['thriller', 'mystery', 'crime', 'fiction', 's...            5764902
# 4   ['mystery', 'thriller', 'crime', 'fiction', 's...              21720
# 5   ['mystery', 'thriller', 'crime', 'fiction', 's...           16071767
# 6   ['mystery', 'thriller', 'crime', 'fiction', 's...              21718
# 7   ['mystery', 'thriller', 'crime', 'fiction', 's...              21721
# 8   ['romance', 'contemporary', 'chick-lit', 'fict...           16117506
# 9   ['mystery', 'thriller', 'crime', 'fiction', 's...              21719
# 10  ['mystery', 'thriller', 'crime', 'fiction', 's...              21722
# 11  ['mystery', 'thriller', 'crime', 'fiction', 's...             182012
# 12  ['horror', 'mystery', 'fiction', 'thriller', '...           18007535
# 13  ['fiction', 'romance', 'contemporary', 'chick-...           25573977
# 14  ['christian', 'romance', 'mystery', 'fiction',...             359463
# 15       ['historical-fiction', 'romance', 'fiction']              72854
# 16  ['classics', 'fiction', 'historical-fiction', ...             275247
# 17  ['historical-fiction', 'fiction', 'art', 'myst...           25664459
# 18                 ['fiction', 'classics', 'fantasy']             906541
# 19   ['fantasy', 'young-adult', 'fiction', 'romance']           12926132
#
#                                             image_url        isbn  \
# 0   https://images.gr-assets.com/books/1294615110m...         NaN
# 1   https://images.gr-assets.com/books/1268350521m...   670060291
