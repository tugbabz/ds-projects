# 14       Fort Worth           Texas        76106  Central  OFF-AP-10002311
# 15       Fort Worth           Texas        76106  Central  OFF-BI-10000756
# 16          Madison       Wisconsin        53711  Central  OFF-ST-10004186
# 17      West Jordan            Utah        84084     West  OFF-ST-10000107
# 18    San Francisco      California        94109     West  OFF-AR-10003056
# 19    San Francisco      California        94109     West  TEC-PH-10001949
# 20    San Francisco      California        94109     West  OFF-BI-10002215
# 21          Fremont        Nebraska        68025  Central  OFF-AR-10000246
# 22          Fremont        Nebraska        68025  Central  OFF-AP-10001492
# 23     Philadelphia    Pennsylvania        19140     East  FUR-CH-10002774
# 24             Orem            Utah        84057     West  FUR-TA-10000577
# 25      Los Angeles      California        90049     West  OFF-BI-10001634
# 26      Los Angeles      California        90049     West  TEC-AC-10003027
# 27     Philadelphia    Pennsylvania        19140     East  FUR-BO-10004834
# 28     Philadelphia    Pennsylvania        19140     East  OFF-BI-10000474
# 29     Philadelphia    Pennsylvania        19140     East  FUR-FU-10004848
# 30     Philadelphia    Pennsylvania        19140     East  OFF-EN-10001509
# 31     Philadelphia    Pennsylvania        19140     East  OFF-AR-10004042
# 32     Philadelphia    Pennsylvania        19140     East  OFF-BI-10001525
# 33     Philadelphia    Pennsylvania        19140     East  OFF-AR-10001683
# 34          Houston           Texas        77095  Central  OFF-PA-10000249
# 35       Richardson           Texas        75080  Central  TEC-PH-10004977
# 36       Richardson           Texas        75080  Central  FUR-FU-10003664
# 37          Houston           Texas        77041  Central  OFF-EN-10002986
# 38          Houston           Texas        77041  Central  FUR-BO-10002545
# 39          Houston           Texas        77041  Central  FUR-CH-10004218
# 40          Houston           Texas        77041  Central  TEC-PH-10000486
# 41       Naperville        Illinois        60540  Central  TEC-PH-10004093
# 42      Los Angeles      California        90049     West  OFF-ST-10003479
# 43        Melbourne         Florida        32935    South  OFF-ST-10003282
# 44            Eagan       Minnesota        55122  Central  TEC-AC-10000171
# 45            Eagan       Minnesota        55122  Central  OFF-BI-10003291
# 46         Westland        Michigan        48185  Central  OFF-ST-10001713
# 47            Dover        Delaware        19901     East  TEC-AC-10002167
# 48            Dover        Delaware        19901     East  TEC-PH-10003988
# 49       New Albany         Indiana        47150  Central  OFF-BI-10004410
#
#            Category Sub-Category  \
# 0         Furniture    Bookcases
# 1         Furniture       Chairs
# 2   Office Supplies       Labels
# 3         Furniture       Tables
# 4   Office Supplies      Storage
# 5         Furniture  Furnishings
# 6   Office Supplies          Art
# 7        Technology       Phones
# 8   Office Supplies      Binders
# 9   Office Supplies   Appliances
# 10        Furniture       Tables
# 11       Technology       Phones
# 12  Office Supplies        Paper
# 13  Office Supplies      Binders
# 14  Office Supplies   Appliances
# 15  Office Supplies      Binders
# 16  Office Supplies      Storage
# 17  Office Supplies      Storage
# 18  Office Supplies          Art
# 19       Technology       Phones
# 20  Office Supplies      Binders
# 21  Office Supplies          Art
# 22  Office Supplies   Appliances
# 23        Furniture       Chairs
# 24        Furniture       Tables
# 25  Office Supplies      Binders
# 26       Technology  Accessories
# 27        Furniture    Bookcases
# 28  Office Supplies      Binders
# 29        Furniture  Furnishings
# 30  Office Supplies    Envelopes
# 31  Office Supplies          Art
# 32  Office Supplies      Binders
# 33  Office Supplies          Art
# 34  Office Supplies        Paper
# 35       Technology       Phones
# 36        Furniture  Furnishings
# 37  Office Supplies    Envelopes
# 38        Furniture    Bookcases
# 39        Furniture       Chairs
# 40       Technology       Phones
# 41       Technology       Phones
# 42  Office Supplies      Storage
# 43  Office Supplies      Storage
# 44       Technology  Accessories
# 45  Office Supplies      Binders
# 46  Office Supplies      Storage
# 47       Technology  Accessories
# 48       Technology       Phones
# 49  Office Supplies      Binders
#
#                                          Product Name      Sales  Quantity  \
# 0                   Bush Somerset Collection Bookcase   261.9600         2
# 1   Hon Deluxe Fabric Upholstered Stacking Chairs,...   731.9400         3
# 2   Self-Adhesive Address Labels for Typewriters b...    14.6200         2
# 3       Bretford CR4500 Series Slim Rectangular Table   957.5775         5
# 4                      Eldon Fold 'N Roll Cart System    22.3680         2
# 5   Eldon Expressions Wood and Plastic Desk Access...    48.8600         7
# 6                                          Newell 322     7.2800         4
# 7                      Mitel 5320 IP Phone VoIP phone   907.1520         6
# 8   DXL Angle-View Binders with Locking Rings by S...    18.5040         3
# 9                    Belkin F5C206VTEL 6 Outlet Surge   114.9000         5
# 10           Chromcraft Rectangular Conference Tables  1706.1840         9
# 11                                              False   911.4240         4
# 12                                         Xerox 1967    15.5520         3
# 13        Fellowes PB200 Plastic Comb Binding Machine   407.9760         3
# 14  Holmes Replacement Filter for HEPA Air Cleaner...    68.8100         5
# 15   Storex DuraTech Recycled Plastic Frosted Binders     2.5440         3
# 16  Stur-D-Stor Shelving, Vertical 5-Shelf: 72"H x...   665.8800         6
# 17                         Fellowes Super Stor/Drawer    55.5000         2
# 18                                         Newell 341     8.5600         2
# 19                            Cisco SPA 501G IP Phone   213.4800         3
# 20        Wilson Jones Hanging View Binder, White, 1"    22.7200         4
# 21                                         Newell 318    19.4600         7
# 22        Acco Six-Outlet Power Strip, 4' Cord Length    60.3400         7
# 23                 Global Deluxe Stacking Chair, Gray    71.3720         2
# 24      Bretford CR4500 Series Slim Rectangular Table  1044.6300         3
# 25                    Wilson Jones Active Use Binders    11.6480         2
# 26                                              False    90.5700         3
# 27  Riverside Palais Royal Lawyers Bookcase, Royal...  3083.4300         7
# 28  Avery Recycled Flexi-View Covers for Binding S...     9.6180         2
# 29  Howard Miller 13-3/4" Diameter Brushed Chrome ...   124.2000         3
# 30                          Poly String Tie Envelopes     3.2640         2
# 31  BOSTON Model 1800 Electric Pencil Sharpeners, ...    86.3040         6
# 32  Acco Pressboard Covers with Storage Hooks, 14 ...     6.8580         6
# 33                                     Lumber Crayons    15.7600         2
# 34                                  Easy-staple paper    29.4720         3
# 35                                        GE 30524EE4  1097.5440         7
# 36  Electrix Architect's Clamp-On Swing Arm Lamp, ...   190.9200         5
# 37  #10-4 1/8" x 9 1/2" Premium Diagonal Seam Enve...   113.3280         9
# 38  Atlantic Metals Mobile 3-Shelf Bookcases, Cust...   532.3992         3
# 39           Global Fabric Manager's Chair, Dark Gray   212.0580         3
# 40                    Plantronics HL10 Handset Lifter   371.1680         4
# 41                                 Panasonic Kx-TS550   147.1680         4
# 42   Eldon Base for stackable storage shelf, platinum    77.8800         2
# 43  Advantus 10-Drawer Portable Organizer, Chrome ...    95.6160         2
# 44  Verbatim 25 GB 6x Blu-ray Single Layer Recorda...    45.9800         2
# 45  Wilson Jones Leather-Like Binders with DublLoc...    17.4600         2
# 46  Gould Plastics 9-Pocket Panel Bin, 18-3/8w x 5...   211.9600         4
# 47                                              False    45.0000         3
# 48  LF Elite 3D Dazzle Designer Hard Case Cover, L...    21.8000         2
# 49  C-Line Peel & Stick Add-On Filing Pockets, 8-3...    38.2200         6
#
#     Discount     Profit
# 0       0.00    41.9136
# 1       0.00   219.5820
# 2       0.00     6.8714
# 3       0.45  -383.0310
# 4       0.20     2.5164
# 5       0.00    14.1694
# 6       0.00     1.9656
# 7       0.20    90.7152
# 8       0.20     5.7825
# 9       0.00    34.4700
# 10      0.20    85.3092
# 11      0.20    68.3568
# 12      0.20     5.4432
# 13      0.20   132.5922
# 14      0.80  -123.8580
# 15      0.80    -3.8160
# 16      0.00    13.3176
# 17      0.00     9.9900
# 18      0.00     2.4824
# 19      0.20    16.0110
# 20      0.20     7.3840
# 21      0.00     5.0596
# 22      0.00    15.6884
# 23      0.30    -1.0196
# 24      0.00   240.2649
# 25      0.20     4.2224
# 26      0.00    11.7741
# 27      0.50 -1665.0522
# 28      0.70    -7.0532
# 29      0.20    15.5250
# 30      0.20     1.1016
# 31      0.20     9.7092
# 32      0.70    -5.7150
# 33      0.20     3.5460
# 34      0.20     9.9468
# 35      0.20   123.4737
# 36      0.60  -147.9630
# 37      0.20    35.4150
# 38      0.32   -46.9764
# 39      0.30   -15.1470
# 40      0.20    41.7564
# 41      0.20    16.5564
# 42      0.00     3.8940
# 43      0.20     9.5616
# 44      0.00    19.7714
# 45      0.00     8.2062
# 46      0.00     8.4784
# 47      0.00     4.9500
# 48      0.00     6.1040
# 49      0.00    17.9634

# %% [markdown]
# ## Data Analysis

# %%
df.describe().T
# Out:
#               count          mean           std       min          25%  \
# Row ID       9994.0   4997.500000   2885.163629     1.000   2499.25000
# Postal Code  9994.0  55190.379428  32063.693350  1040.000  23223.00000
# Sales        9994.0    229.858001    623.245101     0.444     17.28000
# Quantity     9994.0      3.789574      2.225110     1.000      2.00000
# Discount     9994.0      0.156203      0.206452     0.000      0.00000
# Profit       9994.0     28.656896    234.260108 -6599.978      1.72875
#
#                     50%        75%        max
# Row ID        4997.5000   7495.750   9994.000
# Postal Code  56430.5000  90008.000  99301.000
# Sales           54.4900    209.940  22638.480
# Quantity         3.0000      5.000     14.000
# Discount         0.2000      0.200      0.800
# Profit           8.6665     29.364   8399.976

# %%
df["Product ID"].nunique()
# Out:
# 1862

# %%
df["Product ID"].value_counts()
# Out:
# OFF-PA-10001970    19
# TEC-AC-10003832    18
# FUR-FU-10004270    16
# FUR-CH-10001146    15
# TEC-AC-10003628    15
#                    ..
# TEC-PH-10003535     1
# TEC-MA-10002937     1
# OFF-AR-10004974     1
# TEC-AC-10004814     1
# OFF-ST-10001627     1
# Name: Product ID, Length: 1862, dtype: int64

# %%
df["Product Name"].value_counts()
# Out:
# False                                                                                  278
# Staple envelope                                                                         48
# Staples                                                                                 46
# Easy-staple paper                                                                       46
# Avery Non-Stick Binders                                                                 20
#                                                                                       ...
# I.R.I.S IRISCard Anywhere 5 Card Scanner                                                 1
# Canon Color ImageCLASS MF8580Cdw Wireless Laser All-In-One Printer, Copier, Scanner      1
# Xerox 1989                                                                               1
# Belkin 7 Outlet SurgeMaster Surge Protector with Phone Protection                        1
# Eldon Jumbo ProFile Portable File Boxes Graphite/Black                                   1
# Name: Product Name, Length: 1792, dtype: int64

# %%
df.loc[df["Product Name"]==False]["Product ID"].unique()
# Out:
# array(['TEC-PH-10002033', 'TEC-AC-10003027', 'TEC-AC-10002167',
#        'TEC-AC-10001998', 'TEC-AC-10000844', 'TEC-PH-10000215',
#        'TEC-PH-10001254', 'OFF-PA-10000659', 'TEC-AC-10004659',
#        'TEC-AC-10003832', 'TEC-PH-10001580', 'OFF-PA-10000673',
#        'FUR-CH-10003312', 'OFF-PA-10002713', 'OFF-BI-10002412',
#        'TEC-AC-10003911', 'TEC-AC-10004114', 'TEC-AC-10001445',
#        'TEC-PH-10002597', 'FUR-TA-10004256', 'TEC-AC-10001267',
#        'TEC-PH-10004042', 'OFF-PA-10002137', 'TEC-AC-10002253',
#        'TEC-AC-10003610', 'TEC-PH-10001795', 'OFF-PA-10001560',
#        'TEC-AC-10001714', 'TEC-PH-10002923', 'TEC-AC-10004666',
#        'TEC-PH-10004447', 'OFF-PA-10002870', 'TEC-PH-10003437',
#        'OFF-PA-10000466', 'TEC-PH-10004830', 'TEC-AC-10004568',
#        'TEC-PH-10004959', 'TEC-AC-10002217', 'TEC-PH-10003811',
#        'TEC-PH-10002468', 'TEC-PH-10001578', 'TEC-AC-10000358',
#        'TEC-AC-10002637', 'TEC-AC-10000387', 'TEC-AC-10001635',
#        'TEC-PH-10003171', 'TEC-PH-10002415', 'TEC-AC-10002305',
#        'TEC-AC-10000990', 'TEC-AC-10002558', 'TEC-PH-10004434',
#        'TEC-PH-10000193', 'TEC-AC-10004877', 'FUR-FU-10001025',
#        'OFF-PA-10003022', 'TEC-AC-10003870', 'TEC-PH-10001468',
#        'TEC-AC-10002647'], dtype=object)

# %%
df.groupby(["Product ID","Product Name"]).agg({"Quantity": "sum"}).sort_values("Quantity", ascending=False)
# Out:
#                                                                     Quantity
# Product ID      Product Name
# TEC-AC-10003832 False                                                     75
# OFF-BI-10001524 GBC Premium Transparent Covers with Diagonal Li...        67
# FUR-CH-10002647 Situations Contoured Folding Chairs, 4/Set                64
# FUR-TA-10001095 Chromcraft Round Conference Tables                        61
# OFF-BI-10004728 Wilson Jones Turn Tabs Binder Tool for Ring Bin...        59
# ...                                                                      ...
# FUR-BO-10002206 Bush Saratoga Collection 5-Shelf Bookcase, Hano...         1
# FUR-CH-10002317 Global Enterprise Series Seating Low-Back Swive...         1
# OFF-AR-10002704 Boston 1900 Electric Pencil Sharpener                      1
# OFF-PA-10000048 Xerox 20                                                   1
# TEC-MA-10003493 Penpower WorldCard Pro Card Scanner                        1
#
# [1893 rows x 1 columns]

# %%
df["Order ID"].nunique()
# Out:
# 5009

# %%
df.groupby("Order ID").agg({"Sales": "sum"})
# Out:
#                    Sales
# Order ID
# CA-2014-100006   377.970
# CA-2014-100090   699.192
# CA-2014-100293    91.056
# CA-2014-100328     3.928
# CA-2014-100363    21.376
# ...                  ...
# US-2017-168802    18.368
# US-2017-169320   171.430
# US-2017-169488    56.860
# US-2017-169502   113.410
# US-2017-169551  1344.838
#
# [5009 rows x 1 columns]

# %%
df["Price"] = (df["Sales"] + df["Discount"])/df["Quantity"]

# %%
df.sort_values("Price", ascending=False).head()
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 2697    2698  CA-2014-145317   3/18/2014   3/23/2014  Standard Class
# 6826    6827  CA-2016-118689   10/2/2016   10/9/2016  Standard Class
# 4190    4191  CA-2017-166709  11/17/2017  11/22/2017  Standard Class
# 8153    8154  CA-2017-140151   3/23/2017   3/25/2017     First Class
# 2623    2624  CA-2017-127180  10/22/2017  10/24/2017     First Class
#
#      Customer ID Customer Name      Segment        Country           City  \
# 2697    SM-20320   Sean Miller  Home Office  United States   Jacksonville
# 6826    TC-20980  Tamara Chand    Corporate  United States      Lafayette
# 4190    HL-15040  Hunter Lopez     Consumer  United States         Newark
# 8153    RB-19360  Raymond Buch     Consumer  United States        Seattle
# 2623    TA-21385  Tom Ashbrook  Home Office  United States  New York City
#
#            State  Postal Code   Region       Product ID    Category  \
# 2697     Florida        32216    South  TEC-MA-10002412  Technology
# 6826     Indiana        47905  Central  TEC-CO-10004722  Technology
# 4190    Delaware        19711     East  TEC-CO-10004722  Technology
# 8153  Washington        98115     West  TEC-CO-10004722  Technology
# 2623    New York        10024     East  TEC-CO-10004722  Technology
#
#      Sub-Category                                       Product Name  \
# 2697     Machines  Cisco TelePresence System EX90 Videoconferenci...
# 6826      Copiers              Canon imageCLASS 2200 Advanced Copier
# 4190      Copiers              Canon imageCLASS 2200 Advanced Copier
# 8153      Copiers              Canon imageCLASS 2200 Advanced Copier
# 2623      Copiers              Canon imageCLASS 2200 Advanced Copier
#
#           Sales  Quantity  Discount     Profit        Price
# 2697  22638.480         6       0.5 -1811.0784  3773.163333
# 6826  17499.950         5       0.0  8399.9760  3499.990000
# 4190  10499.970         3       0.0  5039.9856  3499.990000
# 8153  13999.960         4       0.0  6719.9808  3499.990000
# 2623  11199.968         4       0.2  3919.9888  2800.042000

# %%
df.sort_values("Sales", ascending=False).head()
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 2697    2698  CA-2014-145317   3/18/2014   3/23/2014  Standard Class
# 6826    6827  CA-2016-118689   10/2/2016   10/9/2016  Standard Class
# 8153    8154  CA-2017-140151   3/23/2017   3/25/2017     First Class
# 2623    2624  CA-2017-127180  10/22/2017  10/24/2017     First Class
# 4190    4191  CA-2017-166709  11/17/2017  11/22/2017  Standard Class
#
#      Customer ID Customer Name      Segment        Country           City  \
# 2697    SM-20320   Sean Miller  Home Office  United States   Jacksonville
# 6826    TC-20980  Tamara Chand    Corporate  United States      Lafayette
# 8153    RB-19360  Raymond Buch     Consumer  United States        Seattle
# 2623    TA-21385  Tom Ashbrook  Home Office  United States  New York City
# 4190    HL-15040  Hunter Lopez     Consumer  United States         Newark
#
#            State  Postal Code   Region       Product ID    Category  \
# 2697     Florida        32216    South  TEC-MA-10002412  Technology
# 6826     Indiana        47905  Central  TEC-CO-10004722  Technology
# 8153  Washington        98115     West  TEC-CO-10004722  Technology
# 2623    New York        10024     East  TEC-CO-10004722  Technology
# 4190    Delaware        19711     East  TEC-CO-10004722  Technology
#
#      Sub-Category                                       Product Name  \
# 2697     Machines  Cisco TelePresence System EX90 Videoconferenci...
# 6826      Copiers              Canon imageCLASS 2200 Advanced Copier
# 8153      Copiers              Canon imageCLASS 2200 Advanced Copier
# 2623      Copiers              Canon imageCLASS 2200 Advanced Copier
# 4190      Copiers              Canon imageCLASS 2200 Advanced Copier
#
#           Sales  Quantity  Discount     Profit        Price
# 2697  22638.480         6       0.5 -1811.0784  3773.163333
# 6826  17499.950         5       0.0  8399.9760  3499.990000
# 8153  13999.960         4       0.0  6719.9808  3499.990000
# 2623  11199.968         4       0.2  3919.9888  2800.042000
# 4190  10499.970         3       0.0  5039.9856  3499.990000

# %%
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# Price            0
# dtype: int64

# %% [markdown]
# ## Creating RFM metrics

# %%
df["Order Date"] = pd.to_datetime(df["Order Date"])

# %%
df["Order Date"].max()
# Out:
# Timestamp('2017-12-30 00:00:00')

# %%
analysis_date = dt.datetime(2018, 0o1, 0o1)

# %%
analysis_date
# Out:
# datetime.datetime(2018, 1, 1, 0, 0)

# %%
rfm = df.groupby("Customer ID").agg({"Order Date": lambda OrderDate: (analysis_date - OrderDate.max()).days,
                                    "Order ID": lambda OrderID: OrderID.nunique(),
                                     "Sales": lambda Sales: Sales.sum()})

# %%
rfm.head()
# Out:
#              Order Date  Order ID     Sales
# Customer ID
# AA-10315            186         5  5563.560
# AA-10375             21         9  1056.390
# AA-10480            261         4  1790.512
# AA-10645             57         6  5086.935
# AB-10015            417         3   886.156

# %%
# The RFM values are generated but it is difficult to compare, therefore RFM scores will be extracted. 
# Monetary is omitted, only recency and frequency are taken into consideration.

rfm.columns = ["recency", "frequency", "monetary"]

# %%
# The customer with the recent login is more valuable, so qcut is done in reverse to give the recent ones a higher score.

rfm["recency_score"] = pd.qcut(rfm['recency'], 5, labels=[5, 4, 3, 2, 1])

# %%
rfm["frequency_score"] = pd.qcut(rfm['frequency'].rank(method="first"), 5, labels=[1, 2, 3, 4, 5])

# %%
rfm["monetary_score"] = pd.qcut(rfm['monetary'], 5, labels=[1, 2, 3, 4, 5])

# %%
rfm["RFM_SCORE"] = (rfm['recency_score'].astype(str) + rfm['frequency_score'].astype(str))

rfm.head()
# Out:
#              recency  frequency  monetary recency_score frequency_score  \
# Customer ID
# AA-10315         186          5  5563.560             2               2
# AA-10375          21          9  1056.390             5               5
# AA-10480         261          4  1790.512             1               1
# AA-10645          57          6  5086.935             3               3
# AB-10015         417          3   886.156             1               1
#
#             monetary_score RFM_SCORE
# Customer ID
# AA-10315                 5        22
# AA-10375                 2        55
# AA-10480                 3        11
# AA-10645                 5        33
# AB-10015                 1        11

# %%
rfm.describe().T
# Out:
#            count         mean          std    min      25%       50%  \
# recency    793.0   148.802018   186.211051  2.000    32.00    77.000
# frequency  793.0     6.316520     2.550885  1.000     5.00     6.000
# monetary   793.0  2896.848500  2628.670117  4.833  1146.05  2256.394
#
#                 75%       max
# recency     185.000   1167.00
# frequency     8.000     17.00
# monetary   3785.276  25043.05

# %%
rfm[rfm["RFM_SCORE"] == "55"].head()
# Out:
#              recency  frequency  monetary recency_score frequency_score  \
# Customer ID
# AA-10375          21          9  1056.390             5               5
# AH-10210           8          9  4805.344             5               5
# AI-10855          15         10  4375.786             5               5
# AT-10735          15         10  3831.864             5               5
# BF-11170          18         11  5907.972             5               5
#
#             monetary_score RFM_SCORE
# Customer ID
# AA-10375                 2        55
# AH-10210                 5        55
# AI-10855                 5        55
# AT-10735                 4        55
# BF-11170                 5        55

# %%
rfm[rfm["RFM_SCORE"] == "11"].head()
# Out:
#              recency  frequency  monetary recency_score frequency_score  \
# Customer ID
# AA-10480         261          4  1790.512             1               1
# AB-10015         417          3   886.156             1               1
# AC-10420         234          3   925.800             1               1
# AF-10885         417          4   861.565             1               1
# AG-10525         847          4  1455.038             1               1
#
#             monetary_score RFM_SCORE
# Customer ID
# AA-10480                 3        11
# AB-10015                 1        11
# AC-10420                 1        11
# AF-10885                 1        11
# AG-10525                 2        11

# %%
# It will be helpful to create a segment column beside the RFM score. With the help of Regex, the segments are generated.

seg_map = {
    r'[1-2][1-2]': 'hibernating',
    r'[1-2][3-4]': 'at_risk',
    r'[1-2]5': 'cant_loose',
    r'3[1-2]': 'about_to_sleep',
    r'33': 'need_attention',
    r'[3-4][4-5]': 'loyal_customers',
    r'41': 'promising',
    r'51': 'new_customers',
    r'[4-5][2-3]': 'potential_loyalists',
    r'5[4-5]': 'champions'
}

# %%
rfm['segment'] = rfm['RFM_SCORE'].replace(seg_map, regex=True)

rfm.head()
# Out:
#              recency  frequency  monetary recency_score frequency_score  \
# Customer ID
# AA-10315         186          5  5563.560             2               2
# AA-10375          21          9  1056.390             5               5
# AA-10480         261          4  1790.512             1               1
# AA-10645          57          6  5086.935             3               3
# AB-10015         417          3   886.156             1               1
#
#             monetary_score RFM_SCORE         segment
# Customer ID
# AA-10315                 5        22     hibernating
# AA-10375                 2        55       champions
# AA-10480                 3        11     hibernating
# AA-10645                 5        33  need_attention
# AB-10015                 1        11     hibernating

# %%
# Here are the number of segments and means of each metric in each segment.

rfm[["segment", "recency", "frequency", "monetary"]].groupby("segment").agg(["mean", "count"])
# Out:
#                         recency       frequency           monetary
#                            mean count      mean count         mean count
# segment
# about_to_sleep        75.438596    57  4.000000    57  2486.855437    57
# at_risk              225.396226   106  6.566038   106  3099.032902   106
# cant_loose           212.871795    39  9.974359    39  4257.519936    39
# champions             15.261364    88  9.056818    88  3933.233999    88
# hibernating          378.549708   171  3.713450   171  1684.111171   171
# loyal_customers       57.812081   149  8.731544   149  3903.655861   149
# need_attention        81.000000    32  6.406250    32  2914.021637    32
# new_customers         15.863636    22  3.272727    22  1082.290400    22
# potential_loyalists   28.321429   112  5.625000   112  2647.323505   112
# promising             41.411765    17  3.294118    17  1858.688000    17

# %%
rfm[rfm["segment"] == "need_attention"].head()
# Out:
#              recency  frequency   monetary recency_score frequency_score  \
# Customer ID
# AA-10645          57          6  5086.9350             3               3
# AG-10675          99          7  3489.0396             3               3
# AH-10120          62          7  1735.5140             3               3
# AJ-10780          77          7  4867.3440             3               3
# AJ-10945          87          7  1839.2400             3               3
#
#             monetary_score RFM_SCORE         segment
# Customer ID
# AA-10645                 5        33  need_attention
# AG-10675                 4        33  need_attention
# AH-10120                 2        33  need_attention
# AJ-10780                 5        33  need_attention
# AJ-10945                 3        33  need_attention

# %%
# Here are the new customers that may play an important role while creating a marketing strategy. 

rfm[rfm["segment"] == "new_customers"].index
# Out:
# Index(['AH-10585', 'AW-10840', 'AY-10555', 'BD-11635', 'BF-11080', 'BN-11470',
#        'CA-12310', 'CM-12115', 'DJ-13630', 'DK-13150', 'EB-13975', 'GD-14590',
#        'GH-14665', 'HE-14800', 'JE-16165', 'JH-15430', 'LT-16765', 'PB-18805',
#        'RR-19315', 'RS-19870', 'SG-20080', 'SK-19990'],
#       dtype='object', name='Customer ID')
