# %% [markdown]
# This project aims to recommend movies to the user by item based and user based collaborative filtering.
#
# In the item based filtering, the item is recommended based on the voting the user had done for other items.
#
# In the user based filtering, the user have the same preferences and same likes with the other users. The item which other users liked is recommended to the user.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/movielense20m/rating.csv
# /kaggle/input/movielense20m/movie.csv

# %% [markdown]
# # Preparing User - Movie Matrix

# %%
pd.set_option('display.max_columns', 20)

# %%
# Two datasets are merged so that both ratings, user ids and movie names take place in the same dataset.

movie = pd.read_csv('../input/movielense20m/movie.csv')
rating = pd.read_csv('../input/movielense20m/rating.csv')
df = movie.merge(rating, how="left", on="movieId")
df.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId  rating            timestamp
# 0     3.0     4.0  1999-12-11 13:36:47
# 1     6.0     5.0  1997-03-13 17:50:52
# 2     8.0     4.0  1996-06-05 13:37:51
# 3    10.0     4.0  1999-11-25 02:44:47
# 4    11.0     4.5  2009-01-02 01:13:41

# %%
# The number of comments for each movie. 

comment_counts = pd.DataFrame(df["title"].value_counts())
comment_counts.head()
# Out:
#                                   title
# Pulp Fiction (1994)               67310
# Forrest Gump (1994)               66172
# Shawshank Redemption, The (1994)  63366
# Silence of the Lambs, The (1991)  63299
# Jurassic Park (1993)              59715

# %%
df.shape
# Out:
# (20000797, 6)

# %%
# Movies which have comments less than 1000 are rare, considering the size of the dataset.

rare_movies = comment_counts[comment_counts["title"] <= 1000].index

# %%
# The rare movies are left out. 

common_movies = df[~df["title"].isin(rare_movies)]

# %%
# A pivot table where user id is the index, movie id is the column and ratings are the values is constructed.

user_movie_df = common_movies.pivot_table(index = ["userId"], columns = ["title"], values = "rating")
user_movie_df.head()
# Out:
# title   'burbs, The (1989)  (500) Days of Summer (2009)  \
# userId
# 1.0                    NaN                          NaN
# 2.0                    NaN                          NaN
# 3.0                    NaN                          NaN
# 4.0                    NaN                          NaN
# 5.0                    NaN                          NaN
#
# title   *batteries not included (1987)  ...And Justice for All (1979)  \
# userId
# 1.0                                NaN                            NaN
# 2.0                                NaN                            NaN
# 3.0                                NaN                            NaN
# 4.0                                NaN                            NaN
# 5.0                                NaN                            NaN
#
# title   10 Things I Hate About You (1999)  10,000 BC (2008)  \
# userId
# 1.0                                   NaN               NaN
# 2.0                                   NaN               NaN
# 3.0                                   NaN               NaN
# 4.0                                   NaN               NaN
# 5.0                                   NaN               NaN
#
# title   101 Dalmatians (1996)  \
# userId
# 1.0                       NaN
# 2.0                       NaN
# 3.0                       NaN
# 4.0                       NaN
# 5.0                       NaN
#
# title   101 Dalmatians (One Hundred and One Dalmatians) (1961)  \
# userId
# 1.0                                                   NaN
# 2.0                                                   NaN
# 3.0                                                   NaN
# 4.0                                                   NaN
# 5.0                                                   NaN
#
# title   102 Dalmatians (2000)  12 Angry Men (1957)  ...  \
# userId                                              ...
# 1.0                       NaN                  NaN  ...
# 2.0                       NaN                  NaN  ...
# 3.0                       NaN                  NaN  ...
# 4.0                       NaN                  NaN  ...
# 5.0                       NaN                  NaN  ...
#
# title   Zero Dark Thirty (2012)  Zero Effect (1998)  Zodiac (2007)  \
# userId
# 1.0                         NaN                 NaN            NaN
# 2.0                         NaN                 NaN            NaN
# 3.0                         NaN                 NaN            NaN
# 4.0                         NaN                 NaN            NaN
# 5.0                         NaN                 NaN            NaN
#
# title   Zombieland (2009)  Zoolander (2001)  Zulu (1964)  [REC] (2007)  \
# userId
# 1.0                   NaN               NaN          NaN           NaN
# 2.0                   NaN               NaN          NaN           NaN
# 3.0                   NaN               NaN          NaN           NaN
# 4.0                   NaN               NaN          NaN           NaN
# 5.0                   NaN               NaN          NaN           NaN
#
# title   eXistenZ (1999)  xXx (2002)  ¡Three Amigos! (1986)
# userId
# 1.0                 NaN         NaN                    NaN
# 2.0                 NaN         NaN                    NaN
# 3.0                 NaN         NaN                    NaN
# 4.0                 NaN         NaN                    NaN
# 5.0                 NaN         NaN                    NaN
#
# [5 rows x 3159 columns]

# %% [markdown]
# # Detecting the movies that the user watched

# %%
# An arbitrary user is picked. The user's id is chosen from the pivot table and assigned to a new dataframe.

user = 108170
user_df = user_movie_df[user_movie_df.index == 108170]
user_df.head()
# Out:
# title     'burbs, The (1989)  (500) Days of Summer (2009)  \
# userId
# 108170.0                 NaN                          NaN
#
# title     *batteries not included (1987)  ...And Justice for All (1979)  \
# userId
# 108170.0                             NaN                            NaN
#
# title     10 Things I Hate About You (1999)  10,000 BC (2008)  \
# userId
# 108170.0                                NaN               NaN
#
# title     101 Dalmatians (1996)  \
# userId
# 108170.0                    NaN
#
# title     101 Dalmatians (One Hundred and One Dalmatians) (1961)  \
# userId
# 108170.0                                                NaN
#
# title     102 Dalmatians (2000)  12 Angry Men (1957)  ...  \
# userId                                                ...
# 108170.0                    NaN                  NaN  ...
#
# title     Zero Dark Thirty (2012)  Zero Effect (1998)  Zodiac (2007)  \
# userId
# 108170.0                      NaN                 NaN            NaN
#
# title     Zombieland (2009)  Zoolander (2001)  Zulu (1964)  [REC] (2007)  \
# userId
# 108170.0                NaN               NaN          NaN           NaN
#
# title     eXistenZ (1999)  xXx (2002)  ¡Three Amigos! (1986)
# userId
# 108170.0              NaN         NaN                    NaN
#
# [1 rows x 3159 columns]

# %%
# NaN values are left out. So the remaining indexes are the movies that the user watched.

movies_watched = user_df.columns[user_df.notna().any()].tolist()

# %% [markdown]
# # Reaching the other users who watched the same movies as the user

# %%
# A new dataframe is constructed with the same columns as the pivot table filtering watched movies of the user.

movies_watched_df = user_movie_df[movies_watched]

movies_watched_df.head()
# Out:
# title   2001: A Space Odyssey (1968)  \
# userId
# 1.0                              3.5
# 2.0                              5.0
# 3.0                              5.0
# 4.0                              NaN
# 5.0                              NaN
#
# title   Adventures of Priscilla, Queen of the Desert, The (1994)  \
# userId
# 1.0                                                   NaN
# 2.0                                                   NaN
# 3.0                                                   NaN
# 4.0                                                   NaN
# 5.0                                                   NaN
#
# title   Akira (1988)  Aladdin (1992)  Aliens (1986)  Almost Famous (2000)  \
# userId
# 1.0              NaN             NaN            4.0                   NaN
# 2.0              NaN             NaN            NaN                   NaN
# 3.0              NaN             NaN            4.0                   NaN
# 4.0              NaN             NaN            NaN                   NaN
# 5.0              NaN             5.0            NaN                   NaN
#
# title   Along Came Polly (2004)  Amadeus (1984)  American History X (1998)  \
# userId
# 1.0                         NaN             NaN                        NaN
# 2.0                         NaN             NaN                        NaN
# 3.0                         NaN             3.0                        4.0
# 4.0                         NaN             NaN                        NaN
# 5.0                         NaN             NaN                        NaN
#
# title   Any Given Sunday (1999)  ...  Untouchables, The (1987)  \
# userId                           ...
# 1.0                         NaN  ...                       3.5
# 2.0                         4.0  ...                       NaN
# 3.0                         NaN  ...                       NaN
# 4.0                         NaN  ...                       NaN
# 5.0                         NaN  ...                       NaN
#
# title   Usual Suspects, The (1995)  Wallace & Gromit: A Close Shave (1995)  \
# userId
# 1.0                            3.5                                     NaN
# 2.0                            NaN                                     NaN
# 3.0                            5.0                                     NaN
# 4.0                            NaN                                     NaN
# 5.0                            NaN                                     NaN
#
# title   Wallace & Gromit: The Best of Aardman Animation (1996)  \
# userId
# 1.0                                                   NaN
# 2.0                                                   NaN
# 3.0                                                   NaN
# 4.0                                                   NaN
# 5.0                                                   5.0
#
# title   Wallace & Gromit: The Wrong Trousers (1993)  \
# userId
# 1.0                                             NaN
# 2.0                                             NaN
# 3.0                                             NaN
# 4.0                                             NaN
# 5.0                                             NaN
#
# title   Wedding Singer, The (1998)  Who Framed Roger Rabbit? (1988)  \
# userId
# 1.0                            NaN                              NaN
# 2.0                            NaN                              NaN
# 3.0                            NaN                              NaN
# 4.0                            NaN                              NaN
# 5.0                            NaN                              NaN
#
# title   Wild at Heart (1990)  Willow (1988)  X2: X-Men United (2003)
# userId
# 1.0                      NaN            4.0                      4.0
# 2.0                      NaN            NaN                      NaN
# 3.0                      NaN            NaN                      NaN
# 4.0                      NaN            NaN                      NaN
# 5.0                      NaN            NaN                      NaN
#
# [5 rows x 186 columns]

# %%
user_movie_count = movies_watched_df.T.notnull().sum()

# %%
user_movie_count
# Out:
# userId
# 1.0         53
# 2.0         11
# 3.0         47
# 4.0          5
# 5.0         16
#             ..
# 138489.0    11
# 138490.0    10
# 138491.0     3
# 138492.0    20
# 138493.0    57
# Length: 138493, dtype: int64

# %%
user_movie_count = user_movie_count.reset_index()

# %%
user_movie_count
# Out:
#           userId   0
# 0            1.0  53
# 1            2.0  11
# 2            3.0  47
# 3            4.0   5
# 4            5.0  16
# ...          ...  ..
# 138488  138489.0  11
# 138489  138490.0  10
# 138490  138491.0   3
# 138491  138492.0  20
# 138492  138493.0  57
#
# [138493 rows x 2 columns]

# %%
# The number of movies each user watched in the movies_watched dataframe, hence the number of movies each user watched commonly with the user.

user_movie_count = movies_watched_df.T.notnull().sum()
user_movie_count = user_movie_count.reset_index()
user_movie_count.columns = ["userId", "movie_count"]
user_movie_count.head()
# Out:
#    userId  movie_count
# 0     1.0           53
# 1     2.0           11
# 2     3.0           47
# 3     4.0            5
# 4     5.0           16

# %% [markdown]
# # Finding the most similar users with the user

# %%
# Watching 60% or over movies with the user is a step to be considered as similar. These similar tasted users are gathered. 
    
perc = len(movies_watched) * 60 / 100
users_same_movies = user_movie_count[user_movie_count["movie_count"] > perc]["userId"]
users_same_movies.head()
# Out:
# 90      91.0
# 115    116.0
# 155    156.0
# 293    294.0
# 297    298.0
# Name: userId, dtype: float64

# %%
movies_watched_df[movies_watched_df.index.isin(users_same_movies)].head()
# Out:
# title   2001: A Space Odyssey (1968)  \
# userId
# 91.0                             2.5
# 116.0                            NaN
# 156.0                            NaN
# 294.0                            4.5
# 298.0                            NaN
#
# title   Adventures of Priscilla, Queen of the Desert, The (1994)  \
# userId
# 91.0                                                  4.0
# 116.0                                                 NaN
# 156.0                                                 3.0
# 294.0                                                 4.0
# 298.0                                                 NaN
#
# title   Akira (1988)  Aladdin (1992)  Aliens (1986)  Almost Famous (2000)  \
# userId
# 91.0             2.5             NaN            4.0                   3.0
# 116.0            NaN             3.0            NaN                   3.0
# 156.0            NaN             NaN            5.0                   5.0
# 294.0            4.5             4.0            4.5                   3.5
# 298.0            NaN             3.0            5.0                   5.0
#
# title   Along Came Polly (2004)  Amadeus (1984)  American History X (1998)  \
# userId
# 91.0                        NaN             3.5                        3.5
# 116.0                       NaN             NaN                        4.5
# 156.0                       NaN             4.0                        NaN
# 294.0                       NaN             2.5                        2.0
# 298.0                       NaN             NaN                        4.0
#
# title   Any Given Sunday (1999)  ...  Untouchables, The (1987)  \
# userId                           ...
# 91.0                        NaN  ...                       4.0
# 116.0                       3.5  ...                       NaN
# 156.0                       NaN  ...                       5.0
# 294.0                       NaN  ...                       NaN
# 298.0                       5.0  ...                       3.0
#
# title   Usual Suspects, The (1995)  Wallace & Gromit: A Close Shave (1995)  \
# userId
# 91.0                           3.5                                     4.0
# 116.0                          4.5                                     NaN
# 156.0                          5.0                                     NaN
# 294.0                          NaN                                     NaN
# 298.0                          5.0                                     NaN
#
# title   Wallace & Gromit: The Best of Aardman Animation (1996)  \
# userId
# 91.0                                                  4.0
# 116.0                                                 NaN
# 156.0                                                 NaN
# 294.0                                                 NaN
# 298.0                                                 NaN
#
# title   Wallace & Gromit: The Wrong Trousers (1993)  \
# userId
# 91.0                                            4.0
# 116.0                                           3.5
# 156.0                                           NaN
# 294.0                                           NaN
# 298.0                                           NaN
#
# title   Wedding Singer, The (1998)  Who Framed Roger Rabbit? (1988)  \
# userId
# 91.0                           3.5                              4.0
# 116.0                          2.0                              3.0
# 156.0                          4.0                              5.0
# 294.0                          1.0                              5.0
# 298.0                          4.0                              3.0
#
# title   Wild at Heart (1990)  Willow (1988)  X2: X-Men United (2003)
# userId
# 91.0                     NaN            3.5                      3.5
# 116.0                    NaN            1.0                      4.5
# 156.0                    NaN            NaN                      NaN
# 294.0                    NaN            4.5                      3.5
# 298.0                    NaN            4.0                      NaN
#
# [5 rows x 186 columns]

# %%
user_df[movies_watched]
# Out:
# title     2001: A Space Odyssey (1968)  \
# userId
# 108170.0                           5.0
#
# title     Adventures of Priscilla, Queen of the Desert, The (1994)  \
# userId
# 108170.0                                                3.5
#
# title     Akira (1988)  Aladdin (1992)  Aliens (1986)  Almost Famous (2000)  \
# userId
# 108170.0           5.0             3.0            5.0                   4.5
#
# title     Along Came Polly (2004)  Amadeus (1984)  American History X (1998)  \
# userId
# 108170.0                      1.0             3.0                        4.5
#
# title     Any Given Sunday (1999)  ...  Untouchables, The (1987)  \
# userId                             ...
# 108170.0                      0.5  ...                       4.0
#
# title     Usual Suspects, The (1995)  Wallace & Gromit: A Close Shave (1995)  \
# userId
# 108170.0                         5.0                                     4.0
#
# title     Wallace & Gromit: The Best of Aardman Animation (1996)  \
# userId
# 108170.0                                                4.5
#
# title     Wallace & Gromit: The Wrong Trousers (1993)  \
# userId
# 108170.0                                          5.0
#
# title     Wedding Singer, The (1998)  Who Framed Roger Rabbit? (1988)  \
# userId
# 108170.0                         4.5                              3.5
#
# title     Wild at Heart (1990)  Willow (1988)  X2: X-Men United (2003)
# userId
# 108170.0                   5.0            4.5                      3.5
#
# [1 rows x 186 columns]

# %%
# Watching the same movies is not enough to be similar. They should both give same ratings for the movies. 

final_df = pd.concat([movies_watched_df[movies_watched_df.index.isin(users_same_movies)],
                      user_df[movies_watched]])
final_df.head()
# Out:
# title   2001: A Space Odyssey (1968)  \
# userId
# 91.0                             2.5
# 116.0                            NaN
# 156.0                            NaN
# 294.0                            4.5
# 298.0                            NaN
#
# title   Adventures of Priscilla, Queen of the Desert, The (1994)  \
# userId
# 91.0                                                  4.0
# 116.0                                                 NaN
# 156.0                                                 3.0
# 294.0                                                 4.0
# 298.0                                                 NaN
#
# title   Akira (1988)  Aladdin (1992)  Aliens (1986)  Almost Famous (2000)  \
# userId
# 91.0             2.5             NaN            4.0                   3.0
# 116.0            NaN             3.0            NaN                   3.0
# 156.0            NaN             NaN            5.0                   5.0
# 294.0            4.5             4.0            4.5                   3.5
# 298.0            NaN             3.0            5.0                   5.0
#
# title   Along Came Polly (2004)  Amadeus (1984)  American History X (1998)  \
# userId
# 91.0                        NaN             3.5                        3.5
# 116.0                       NaN             NaN                        4.5
# 156.0                       NaN             4.0                        NaN
# 294.0                       NaN             2.5                        2.0
# 298.0                       NaN             NaN                        4.0
#
# title   Any Given Sunday (1999)  ...  Untouchables, The (1987)  \
# userId                           ...
# 91.0                        NaN  ...                       4.0
# 116.0                       3.5  ...                       NaN
# 156.0                       NaN  ...                       5.0
# 294.0                       NaN  ...                       NaN
# 298.0                       5.0  ...                       3.0
#
# title   Usual Suspects, The (1995)  Wallace & Gromit: A Close Shave (1995)  \
# userId
# 91.0                           3.5                                     4.0
# 116.0                          4.5                                     NaN
# 156.0                          5.0                                     NaN
# 294.0                          NaN                                     NaN
# 298.0                          5.0                                     NaN
#
# title   Wallace & Gromit: The Best of Aardman Animation (1996)  \
# userId
# 91.0                                                  4.0
# 116.0                                                 NaN
# 156.0                                                 NaN
# 294.0                                                 NaN
# 298.0                                                 NaN
#
# title   Wallace & Gromit: The Wrong Trousers (1993)  \
# userId
# 91.0                                            4.0
# 116.0                                           3.5
# 156.0                                           NaN
# 294.0                                           NaN
# 298.0                                           NaN
#
# title   Wedding Singer, The (1998)  Who Framed Roger Rabbit? (1988)  \
# userId
# 91.0                           3.5                              4.0
# 116.0                          2.0                              3.0
# 156.0                          4.0                              5.0
# 294.0                          1.0                              5.0
# 298.0                          4.0                              3.0
#
# title   Wild at Heart (1990)  Willow (1988)  X2: X-Men United (2003)
# userId
# 91.0                     NaN            3.5                      3.5
# 116.0                    NaN            1.0                      4.5
# 156.0                    NaN            NaN                      NaN
# 294.0                    NaN            4.5                      3.5
# 298.0                    NaN            4.0                      NaN
#
# [5 rows x 186 columns]

# %%
final_df.T.corr().head()
# Out:
# userId  91.0      116.0     156.0     294.0     298.0     359.0     367.0     \
# userId
# 91.0    1.000000  0.454166  0.322393  0.338482  0.152716  0.245899  0.505629
# 116.0   0.454166  1.000000  0.460489  0.173071  0.347831  0.186010  0.539608
# 156.0   0.322393  0.460489  1.000000  0.219779  0.339833  0.201932  0.499251
# 294.0   0.338482  0.173071  0.219779  1.000000  0.276074 -0.046278  0.422012
# 298.0   0.152716  0.347831  0.339833  0.276074  1.000000  0.029420  0.400850
#
# userId  388.0     586.0     614.0     ...  137686.0  137839.0  137854.0  \
# userId                                ...
# 91.0    0.438347  0.188644  0.572365  ...  0.437469  0.311582  0.529880
# 116.0   0.639885  0.594176  0.445155  ...  0.540097  0.476253  0.444682
# 156.0   0.416804  0.369159  0.317214  ...  0.477000  0.363992  0.411427
# 294.0   0.239812  0.224724  0.151781  ...  0.283390  0.210880  0.233735
# 298.0   0.170610  0.330291 -0.050431  ...  0.337318  0.129187  0.204721
#
# userId  137885.0  138134.0  138208.0  138254.0  138325.0  138411.0  108170.0
# userId
# 91.0    0.419165  0.267141  0.548877  0.199193  0.371530  0.521917  0.328344
# 116.0   0.517867  0.419395  0.420043  0.568327  0.481510  0.477922  0.497016
# 156.0   0.347840  0.041885  0.346490  0.439030  0.342354  0.441789  0.514391
# 294.0   0.282503  0.137793  0.212778  0.286854  0.322522  0.307772  0.237754
# 298.0   0.322179  0.043679  0.215007  0.333704  0.036160  0.160045  0.214872
#
# [5 rows x 2327 columns]

# %%
corr_df = final_df.T.corr().stack().sort_values().drop_duplicates()

# %%
corr_df.head()
# Out:
# userId    userId
# 72838.0   110130.0   -0.581570
# 100618.0  33581.0    -0.481252
# 89242.0   126121.0   -0.476220
# 72838.0   7232.0     -0.472418
# 20011.0   104973.0   -0.458733
# dtype: float64

# %%
corr_df = pd.DataFrame(corr_df, columns=["corr"])

# %%
corr_df.head()
# Out:
#                        corr
# userId   userId
# 72838.0  110130.0 -0.581570
# 100618.0 33581.0  -0.481252
# 89242.0  126121.0 -0.476220
# 72838.0  7232.0   -0.472418
# 20011.0  104973.0 -0.458733

# %%
corr_df.index.names = ['user_id_1', 'user_id_2']
corr_df = corr_df.reset_index()

# %%
# The correlation between each user ratings are specified and sorted in descending order. 
corr_df.head()
# Out:
#    user_id_1  user_id_2      corr
# 0    72838.0   110130.0 -0.581570
# 1   100618.0    33581.0 -0.481252
# 2    89242.0   126121.0 -0.476220
# 3    72838.0     7232.0 -0.472418
# 4    20011.0   104973.0 -0.458733

# %%
# One of the users in the correlation table should be the first user. To be considered as similar, the correlation threshold value is taken 0.65.

top_users = corr_df[(corr_df["user_id_1"] == user) & (corr_df["corr"] >= 0.65)][["user_id_2", "corr"]].reset_index(drop=True)
top_users = top_users.sort_values(by='corr', ascending=False)

# %%
top_users.rename(columns={"user_id_2": "userId"}, inplace=True)
top_users.head()
# Out:
#      userId      corr
# 3  108170.0  1.000000
# 2    5155.0  0.716406
# 1  121747.0  0.673295
# 0  121747.0  0.673295

# %%
# The movie id and the rating data are merged with the correlation data. The highest correlation belongs to the user himself, so it is removed.

rating = pd.read_csv('../input/movielense20m/rating.csv')
top_users_ratings = top_users.merge(rating[["userId", "movieId", "rating"]], how='inner')

# %%
top_users_ratings = top_users_ratings[top_users_ratings["userId"] != user]
top_users_ratings.head()
# Out:
#      userId      corr  movieId  rating
# 194  5155.0  0.716406        1     3.5
# 195  5155.0  0.716406        2     3.0
# 196  5155.0  0.716406        5     3.0
# 197  5155.0  0.716406        9     3.0
# 198  5155.0  0.716406       10     4.0

# %% [markdown]
# # The calculation of Weighted Average Recommendation Score

# %%
# It is wanted to have the suggestion from the most similar ones, however rating may differ among the most similar ones. So a scale is 
# arranged with correlation and rating.

top_users_ratings['weighted_rating'] = top_users_ratings['corr'] * top_users_ratings['rating']
top_users_ratings.head()
# Out:
#      userId      corr  movieId  rating  weighted_rating
# 194  5155.0  0.716406        1     3.5         2.507423
# 195  5155.0  0.716406        2     3.0         2.149219
# 196  5155.0  0.716406        5     3.0         2.149219
# 197  5155.0  0.716406        9     3.0         2.149219
# 198  5155.0  0.716406       10     4.0         2.865626

# %% [markdown]
# # User Based Recommendation

# %%
# The weighted average scores are sorted according to movie id.

recommendation_df = top_users_ratings.groupby('movieId').agg({"weighted_rating": "mean"})
recommendation_df = recommendation_df.reset_index()
recommendation_df.head()
# Out:
#    movieId  weighted_rating
# 0        1         2.406830
# 1        2         1.614134
# 2        5         2.149219
# 3        6         2.693181
# 4        9         2.149219

# %%
# The movies having score greater than 3.5 are selected.

movies_to_be_recommend = recommendation_df[recommendation_df["weighted_rating"] > 3.5].sort_values("weighted_rating", ascending=False)

# %%
# The movie names are needed so the datasets are merged. So here is the list of the movies to recommend for the specified user. 

movie = pd.read_csv('../input/movielense20m/movie.csv')
movies_to_be_recommend.merge(movie[["movieId", "title"]])["title"]
# Out:
# 0                        Natural Born Killers (1994)
# 1     Mystery Science Theater 3000: The Movie (1996)
# 2             One Flew Over the Cuckoo's Nest (1975)
# 3                         Princess Bride, The (1987)
# 4          Butch Cassidy and the Sundance Kid (1969)
# 5                                  Birds, The (1963)
# 6              Fear and Loathing in Las Vegas (1998)
# 7                               Exorcist, The (1973)
# 8                          Christmas Story, A (1983)
# 9                                Natural, The (1984)
# 10             Jay and Silent Bob Strike Back (2001)
# 11                             Super Troopers (2001)
# 12      Anchorman: The Legend of Ron Burgundy (2004)
# Name: title, dtype: object

# %% [markdown]
# # Item Based Recommendation

# %%
# The movie id which the user last watched and rated high

movie_id = rating[(rating["userId"] == user) & (rating["rating"] == 5.0)].sort_values(by = "timestamp", ascending = False)["movieId"][0:1].values[0]

# %%
# A pivot table where user id is the index, movie name is the column and ratings are the values is constructed.

user_moviename_df = common_movies.pivot_table(index = ["userId"], columns = ["title"], values = "rating")

# %%
# The function gets the movie name from the pivot table, and brigns the most correlated movies with it in descending order.

def item_based_recommender(movie_name, user_moviename_df):
    movie = user_moviename_df[movie_name]
    return user_moviename_df.corrwith(movie).sort_values(ascending=False).head(10)


movies_from_item_based = item_based_recommender(movie[movie["movieId"] == movie_id]["title"].values[0], user_moviename_df)

# %%
# These are the 5 movies to suggest to the user based on his taste.

movies_from_item_based[1:6].index
# Out:
# Index(['My Science Project (1985)', 'Mediterraneo (1991)',
#        'Old Man and the Sea, The (1958)',
#        'National Lampoon's Senior Trip (1995)', 'Clockwatchers (1997)'],
#       dtype='object', name='title')
